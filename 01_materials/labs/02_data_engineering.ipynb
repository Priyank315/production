# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %%
src = os.getenv('SRC_DIR')
print(src)
# Out:
# ../../05_src/

# %%
sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")
px
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-12-02 00:00:00-05:00   17.386038   17.583266   17.162326   17.175100
# 2013-12-03 00:00:00-05:00   17.395380   17.647136   17.376063   17.645266
# 2013-12-04 00:00:00-05:00   17.619718   17.734690   17.473899   17.604139
# 2013-12-05 00:00:00-05:00   17.842492   17.920075   17.648068   17.694492
# 2013-12-06 00:00:00-05:00   17.628755   17.658667   17.434955   17.448975
# ...                               ...         ...         ...         ...
# 2024-01-25 00:00:00-05:00  194.268273  195.313157  192.168559  193.223389
# 2024-01-26 00:00:00-05:00  193.322905  193.810507  191.004263  191.481918
# 2024-01-29 00:00:00-05:00  191.073922  191.262998  188.655776  190.795288
# 2024-01-30 00:00:00-05:00  190.009147  190.864955  186.556062  187.123276
# 2024-01-31 00:00:00-05:00  186.128151  186.187872  183.451278  183.501022
#
#                               Volume  Dividends  Stock Splits
# Date
# 2013-12-02 00:00:00-05:00  472544800        0.0           0.0
# 2013-12-03 00:00:00-05:00  450968000        0.0           0.0
# 2013-12-04 00:00:00-05:00  377809600        0.0           0.0
# 2013-12-05 00:00:00-05:00  447580000        0.0           0.0
# 2013-12-06 00:00:00-05:00  344352400        0.0           0.0
# ...                              ...        ...           ...
# 2024-01-25 00:00:00-05:00   54822100        0.0           0.0
# 2024-01-26 00:00:00-05:00   44594000        0.0           0.0
# 2024-01-29 00:00:00-05:00   47145600        0.0           0.0
# 2024-01-30 00:00:00-05:00   55859400        0.0           0.0
# 2024-01-31 00:00:00-05:00   55467800        0.0           0.0
#
# [2558 rows x 7 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)
tickers
# Out:
#     ticker                                Security             GICS Sector  \
# 268    JCI                        Johnson Controls             Industrials
# 73     BSX                       Boston Scientific             Health Care
# 289    LIN                               Linde plc               Materials
# 155    DOW                                Dow Inc.               Materials
# 104    CVX                     Chevron Corporation                  Energy
# 280    KHC                             Kraft Heinz        Consumer Staples
# 392     RL                Ralph Lauren Corporation  Consumer Discretionary
# 124     ED                     Consolidated Edison               Utilities
# 68      BX                              Blackstone              Financials
# 244    IBM                                     IBM  Information Technology
# 9        A                    Agilent Technologies             Health Care
# 195    FIS  Fidelity National Information Services              Financials
# 304    MAS                                   Masco             Industrials
# 84     CPB                   Campbell Soup Company        Consumer Staples
# 373    PNW                           Pinnacle West               Utilities
# 390   QCOM                                Qualcomm  Information Technology
# 498    YUM                             Yum! Brands  Consumer Discretionary
# 30     AWK                    American Water Works               Utilities
# 317     MU                       Micron Technology  Information Technology
# 407    RCL                   Royal Caribbean Group  Consumer Discretionary
# 493    WTW                    Willis Towers Watson              Financials
# 494    GWW                          W. W. Grainger             Industrials
# 225    HAS                                  Hasbro  Consumer Discretionary
# 227   PEAK                              Healthpeak             Real Estate
# 76      BR          Broadridge Financial Solutions             Industrials
# 464    VLO                           Valero Energy                  Energy
# 473   VICI                         Vici Properties             Real Estate
# 402    RHI                             Robert Half             Industrials
# 101    CRL              Charles River Laboratories             Health Care
# 335    NEM                                 Newmont               Materials
# 296    LYB                          LyondellBasell               Materials
# 222     GS                           Goldman Sachs              Financials
# 474      V                               Visa Inc.              Financials
# 173   EPAM                            EPAM Systems  Information Technology
# 2      ABT                                  Abbott             Health Care
# 334   NFLX                                 Netflix  Communication Services
# 272   KVUE                                  Kenvue        Consumer Staples
# 70    BKNG                        Booking Holdings  Consumer Discretionary
# 210     IT                                 Gartner  Information Technology
# 63     BBY                                Best Buy  Consumer Discretionary
# 347    NUE                                   Nucor               Materials
# 93    CBRE                              CBRE Group             Real Estate
# 488    WDC                         Western Digital  Information Technology
# 185   EXPE                           Expedia Group  Consumer Discretionary
# 33    AMGN                                   Amgen             Health Care
# 77     BRO                           Brown & Brown              Financials
# 0      MMM                                      3M             Industrials
# 11    ABNB                                  Airbnb  Consumer Discretionary
# 310    MDT                               Medtronic             Health Care
# 22    AMZN                                  Amazon  Consumer Discretionary
#
#                                 GICS Sub-Industry  \
# 268                             Building Products
# 73                          Health Care Equipment
# 289                              Industrial Gases
# 155                           Commodity Chemicals
# 104                          Integrated Oil & Gas
# 280                        Packaged Foods & Meats
# 392           Apparel, Accessories & Luxury Goods
# 124                               Multi-Utilities
# 68               Asset Management & Custody Banks
# 244                IT Consulting & Other Services
# 9                  Life Sciences Tools & Services
# 195     Transaction & Payment Processing Services
# 304                             Building Products
# 84                         Packaged Foods & Meats
# 373                               Multi-Utilities
# 390                                Semiconductors
# 498                                   Restaurants
# 30                                Water Utilities
# 317                                Semiconductors
# 407                Hotels, Resorts & Cruise Lines
# 493                             Insurance Brokers
# 494  Industrial Machinery & Supplies & Components
# 225                              Leisure Products
# 227                             Health Care REITs
# 76          Data Processing & Outsourced Services
# 464                Oil & Gas Refining & Marketing
# 473                          Hotel & Resort REITs
# 402          Human Resource & Employment Services
# 101                Life Sciences Tools & Services
# 335                                          Gold
# 296                           Specialty Chemicals
# 222                Investment Banking & Brokerage
# 474     Transaction & Payment Processing Services
# 173                IT Consulting & Other Services
# 2                           Health Care Equipment
# 334                        Movies & Entertainment
# 272                        Personal Care Products
# 70                 Hotels, Resorts & Cruise Lines
# 210                IT Consulting & Other Services
# 63                  Computer & Electronics Retail
# 347                                         Steel
# 93                           Real Estate Services
# 488    Technology Hardware, Storage & Peripherals
# 185                Hotels, Resorts & Cruise Lines
# 33                                  Biotechnology
# 77                              Insurance Brokers
# 0                        Industrial Conglomerates
# 11                 Hotels, Resorts & Cruise Lines
# 310                         Health Care Equipment
# 22                               Broadline Retail
#
#                            Headquarters Location  Date added      CIK  \
# 268                                Cork, Ireland       40417   833444
# 73                    Marlborough, Massachusetts       34754   885725
# 289                    Guildford, United Kingdom       33786  1707925
# 155                            Midland, Michigan       43556  1751788
# 104                        San Ramon, California       20883    93410
# 280  Chicago, Illinois; Pittsburgh, Pennsylvania       42191  1637459
# 392                      New York City, New York       39115  1037038
# 124                      New York City, New York       20883  1047862
# 68                       New York City, New York       45187  1393818
# 244                             Armonk, New York       20883    51143
# 9                        Santa Clara, California       36682  1090872
# 195                        Jacksonville, Florida       39031  1136893
# 304                            Livonia, Michigan       29767    62996
# 84                            Camden, New Jersey       20883    16732
# 373                             Phoenix, Arizona       36437   764622
# 390                        San Diego, California       36363   804328
# 498                         Louisville, Kentucky       35709  1041061
# 30                            Camden, New Jersey       42433  1410636
# 317                                 Boise, Idaho       34604   723125
# 407                               Miami, Florida       41978   884887
# 493                       London, United Kingdom       42374  1140536
# 494                        Lake Forest, Illinois       29767   277135
# 225                      Pawtucket, Rhode Island       30955    46080
# 227                       Long Beach, California       39538   765880
# 76                        Lake Success, New York       43269  1383312
# 464                           San Antonio, Texas       37610  1035002
# 473                      New York City, New York       44720  1705696
# 402                       Menlo Park, California       36865   315213
# 101                    Wilmington, Massachusetts       44330  1100682
# 335                             Denver, Colorado       25384  1164727
# 296                       Rotterdam, Netherlands       41157  1489393
# 222                      New York City, New York       37459   886982
# 474                    San Francisco, California       40168  1403161
# 173                        Newtown, Pennsylvania       44544  1352010
# 2                        North Chicago, Illinois       20883     1800
# 334                        Los Gatos, California       40532  1065280
# 272                         Skillman, New Jersey       45163  1944048
# 70                          Norwalk, Connecticut       40123  1075531
# 210                        Stamford, Connecticut       42830   749251
# 63                          Richfield, Minnesota       36340   764478
# 347                    Charlotte, North Carolina       31167    73309
# 93                                 Dallas, Texas       39031  1138118
# 488                         San Jose, California       39995   106040
# 185                          Seattle, Washington       39357  1324424
# 33                     Thousand Oaks, California       33605   318154
# 77                        Daytona Beach, Florida       44459    79282
# 0                          Saint Paul, Minnesota       20883    66740
# 11                     San Francisco, California       45187  1559720
# 310                              Dublin, Ireland       31716  1613103
# 22                           Seattle, Washington       38674  1018724
#
#                               Founded
# 268                              1885
# 73                               1979
# 289                              1879
# 155                       2019 (1897)
# 104                              1879
# 280                       2015 (1869)
# 392                              1967
# 124                              1823
# 68                               1985
# 244                              1911
# 9                                1999
# 195                              1968
# 304                              1929
# 84                               1869
# 373                              1985
# 390                              1985
# 498                              1997
# 30                               1886
# 317                              1978
# 407                              1997
# 493                              2016
# 494                              1927
# 225                              1923
# 227                              1985
# 76                               1962
# 464                              1980
# 473                              2017
# 402                              1948
# 101                              1947
# 335                              1921
# 296                              2007
# 222                              1869
# 474                              1958
# 173                              1993
# 2                                1888
# 334                              1997
# 272  2022 (Johnson & Johnson spinoff)
# 70                               1996
# 210                              1979
# 63                               1966
# 347                              1940
# 93                               1906
# 488                              1970
# 185                              1996
# 33                               1980
# 77                               1939
# 0                                1902
# 11                               2008
# 310                              1949
# 22                               1994

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; no timezone found
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %%
px_list[0]
# Out:
#                           Date       Open       High        Low      Close  \
# 0    2013-12-02 00:00:00-05:00  27.627356  27.808163  27.215115  27.265741
# 1    2013-12-03 00:00:00-05:00  27.121090  27.439310  27.055999  27.381451
# 2    2013-12-04 00:00:00-05:00  27.236810  27.461011  26.831801  27.128326
# 3    2013-12-05 00:00:00-05:00  27.128324  27.258505  26.882426  26.940285
# 4    2013-12-06 00:00:00-05:00  26.904127  27.410386  26.860732  27.301903
# ...                        ...        ...        ...        ...        ...
# 2553 2024-01-25 00:00:00-05:00  54.762314  54.850879  53.817624  54.811516
# 2554 2024-01-26 00:00:00-05:00  54.949284  57.074829  54.624546  55.687321
# 2555 2024-01-29 00:00:00-05:00  55.490510  55.766042  54.909921  55.746365
# 2556 2024-01-30 00:00:00-05:00  54.427739  54.998485  52.361234  53.620819
# 2557 2024-01-31 00:00:00-05:00  53.089433  53.404328  51.190218  51.849529
#
#         Volume  Dividends  Stock Splits ticker
# 0      2404404        0.0           0.0    JCI
# 1      3774065        0.0           0.0    JCI
# 2      3876632        0.0           0.0    JCI
# 3      2503342        0.0           0.0    JCI
# 4      2879516        0.0           0.0    JCI
# ...        ...        ...           ...    ...
# 2553   6448900        0.0           0.0    JCI
# 2554  10346200        0.0           0.0    JCI
# 2555   9004300        0.0           0.0    JCI
# 2556  10868700        0.0           0.0    JCI
# 2557  11717500        0.0           0.0    JCI
#
# [2558 rows x 9 columns]

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 1.215674877166748 seconds.
# Csv file size 14.154983 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 0.15907049179077148 seconds.
# Parquet file size 5.561764 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\prsrivastava\AppData\Local\Temp\ipykernel_17148\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.875483   35.005930   34.640675
# A      2013-12-03 00:00:00-05:00   34.516748   34.679811   34.281940
# A      2013-12-04 00:00:00-05:00   34.464560   35.110283   34.386293
# A      2013-12-05 00:00:00-05:00   34.797195   35.090704   34.647179
# A      2013-12-06 00:00:00-05:00   35.064632   35.827754   35.064632
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  127.913548  128.386458  126.642582
# YUM    2024-01-26 00:00:00-05:00  128.002213  128.760851  126.770665
# YUM    2024-01-29 00:00:00-05:00  127.194317  128.622910  126.396261
# YUM    2024-01-30 00:00:00-05:00  128.435707  129.283013  127.667222
# YUM    2024-01-31 00:00:00-05:00  129.509619  130.031795  127.351944
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.705898  2039962        0.0           0.0  2013          NaN
# A        34.523270  3462706        0.0           0.0  2013    34.705898
# A        34.947220  3377288        0.0           0.0  2013    34.523270
# A        34.895031  2530939        0.0           0.0  2013    34.947220
# A        35.762531  4268513        0.0           0.0  2013    34.895031
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.297791  1871700        0.0           0.0  2024   127.529305
# YUM     127.184464  1157000        0.0           0.0  2024   128.297791
# YUM     128.622910  1482100        0.0           0.0  2024   127.184464
# YUM     128.691864  1421500        0.0           0.0  2024   128.622910
# YUM     127.578560  2154200        0.0           0.0  2024   128.691864
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-11-24 21:44:03,898, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-11-24 21:44:03,898, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-11-24 21:44:03,900, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-11-24 21:44:03,900, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-11-24 21:44:03,906, data_manager.py, 58, INFO, Processing all tickers
# 2024-11-24 21:44:03,906, data_manager.py, 58, INFO, Processing all tickers
# 2024-11-24 21:44:03,907, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-11-24 21:44:03,907, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-11-24 21:44:03,908, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:03,908, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:04,249, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-11-24 21:44:04,249, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-11-24 21:44:04,987, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-11-24 21:44:04,987, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-11-24 21:44:04,989, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:04,989, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:05,301, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-11-24 21:44:05,301, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-11-24 21:44:06,016, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-11-24 21:44:06,016, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-11-24 21:44:06,017, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:06,017, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:06,389, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-11-24 21:44:06,389, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-11-24 21:44:07,125, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-11-24 21:44:07,125, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-11-24 21:44:07,126, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:07,126, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:07,338, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-11-24 21:44:07,338, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-11-24 21:44:07,681, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-11-24 21:44:07,681, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-11-24 21:44:07,683, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:07,683, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:07,965, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-11-24 21:44:07,965, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-11-24 21:44:08,669, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-11-24 21:44:08,669, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-11-24 21:44:08,671, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:08,671, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:08,967, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-11-24 21:44:08,967, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-11-24 21:44:09,655, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-11-24 21:44:09,655, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-11-24 21:44:09,657, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:09,657, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:09,945, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-11-24 21:44:09,945, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-11-24 21:44:10,729, data_manager.py, 73, INFO, Processing ticker AES
# 2024-11-24 21:44:10,729, data_manager.py, 73, INFO, Processing ticker AES
# 2024-11-24 21:44:10,731, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:10,731, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:11,032, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-11-24 21:44:11,032, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-11-24 21:44:11,722, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-11-24 21:44:11,722, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-11-24 21:44:11,723, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:11,723, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:12,041, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-11-24 21:44:12,041, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-11-24 21:44:12,745, data_manager.py, 73, INFO, Processing ticker A
# 2024-11-24 21:44:12,745, data_manager.py, 73, INFO, Processing ticker A
# 2024-11-24 21:44:12,747, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:12,747, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:13,065, data_manager.py, 83, INFO, Saving data for A by year
# 2024-11-24 21:44:13,065, data_manager.py, 83, INFO, Saving data for A by year
# 2024-11-24 21:44:13,778, data_manager.py, 73, INFO, Processing ticker APD
# 2024-11-24 21:44:13,778, data_manager.py, 73, INFO, Processing ticker APD
# 2024-11-24 21:44:13,780, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:13,780, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:14,121, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-11-24 21:44:14,121, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-11-24 21:44:14,808, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-11-24 21:44:14,808, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-11-24 21:44:14,810, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:14,810, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:14,947, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-11-24 21:44:14,947, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-11-24 21:44:15,185, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-11-24 21:44:15,185, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-11-24 21:44:15,186, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:15,186, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:15,396, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-11-24 21:44:15,396, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-11-24 21:44:16,125, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-11-24 21:44:16,125, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-11-24 21:44:16,127, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:16,127, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:16,440, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-11-24 21:44:16,440, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-11-24 21:44:17,137, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-11-24 21:44:17,137, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-11-24 21:44:17,138, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:17,138, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:17,433, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-11-24 21:44:17,433, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-11-24 21:44:18,122, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-11-24 21:44:18,122, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-11-24 21:44:18,123, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:18,123, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:18,376, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-11-24 21:44:18,376, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-11-24 21:44:19,010, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-11-24 21:44:19,010, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-11-24 21:44:19,011, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:19,011, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:19,228, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-11-24 21:44:19,228, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-11-24 21:44:19,579, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-11-24 21:44:19,579, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-11-24 21:44:19,580, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:19,580, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:19,893, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-11-24 21:44:19,893, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-11-24 21:44:20,636, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-11-24 21:44:20,636, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-11-24 21:44:20,638, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:20,638, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:20,940, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-11-24 21:44:20,940, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-11-24 21:44:21,608, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-11-24 21:44:21,608, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-11-24 21:44:21,609, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:21,609, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:21,903, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-11-24 21:44:21,903, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-11-24 21:44:22,472, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-11-24 21:44:22,472, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-11-24 21:44:22,474, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:22,474, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:22,841, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-11-24 21:44:22,841, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-11-24 21:44:23,448, data_manager.py, 73, INFO, Processing ticker MO
# 2024-11-24 21:44:23,448, data_manager.py, 73, INFO, Processing ticker MO
# 2024-11-24 21:44:23,449, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:23,449, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:23,761, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-11-24 21:44:23,761, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-11-24 21:44:24,462, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-11-24 21:44:24,462, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-11-24 21:44:24,463, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:24,463, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:24,742, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-11-24 21:44:24,742, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-11-24 21:44:25,420, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-11-24 21:44:25,420, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-11-24 21:44:25,422, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:25,422, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:25,626, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-11-24 21:44:25,626, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-11-24 21:44:26,023, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-11-24 21:44:26,023, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-11-24 21:44:26,024, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:26,024, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:26,326, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-11-24 21:44:26,326, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-11-24 21:44:27,041, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-11-24 21:44:27,041, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-11-24 21:44:27,042, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:27,042, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:27,292, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-11-24 21:44:27,292, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-11-24 21:44:27,879, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-11-24 21:44:27,879, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-11-24 21:44:27,880, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:27,880, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:28,232, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-11-24 21:44:28,232, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-11-24 21:44:28,947, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-11-24 21:44:28,947, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-11-24 21:44:28,949, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:28,949, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:29,352, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-11-24 21:44:29,352, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-11-24 21:44:30,113, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-11-24 21:44:30,113, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-11-24 21:44:30,114, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:30,114, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:30,521, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-11-24 21:44:30,521, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-11-24 21:44:31,309, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-11-24 21:44:31,309, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-11-24 21:44:31,310, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:31,310, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:31,629, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-11-24 21:44:31,629, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-11-24 21:44:32,311, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-11-24 21:44:32,311, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-11-24 21:44:32,312, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:32,312, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:32,559, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-11-24 21:44:32,559, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-11-24 21:44:33,065, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-11-24 21:44:33,065, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-11-24 21:44:33,067, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:33,067, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:33,309, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-11-24 21:44:33,309, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-11-24 21:44:33,929, data_manager.py, 73, INFO, Processing ticker AME
# 2024-11-24 21:44:33,929, data_manager.py, 73, INFO, Processing ticker AME
# 2024-11-24 21:44:33,930, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:33,930, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:34,261, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-11-24 21:44:34,261, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-11-24 21:44:34,942, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-11-24 21:44:34,942, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-11-24 21:44:34,942, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:34,942, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:35,215, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-11-24 21:44:35,215, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-11-24 21:44:35,944, data_manager.py, 73, INFO, Processing ticker APH
# 2024-11-24 21:44:35,944, data_manager.py, 73, INFO, Processing ticker APH
# 2024-11-24 21:44:35,945, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:35,945, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:36,383, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-11-24 21:44:36,383, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-11-24 21:44:37,143, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-11-24 21:44:37,143, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-11-24 21:44:37,145, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:37,145, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:37,449, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-11-24 21:44:37,449, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-11-24 21:44:38,222, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-11-24 21:44:38,222, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-11-24 21:44:38,223, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:38,223, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:38,495, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-11-24 21:44:38,495, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-11-24 21:44:39,221, data_manager.py, 73, INFO, Processing ticker AON
# 2024-11-24 21:44:39,221, data_manager.py, 73, INFO, Processing ticker AON
# 2024-11-24 21:44:39,222, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:39,222, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:39,521, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-11-24 21:44:39,521, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-11-24 21:44:40,262, data_manager.py, 73, INFO, Processing ticker APA
# 2024-11-24 21:44:40,262, data_manager.py, 73, INFO, Processing ticker APA
# 2024-11-24 21:44:40,264, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:40,264, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:40,601, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-11-24 21:44:40,601, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-11-24 21:44:41,312, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-11-24 21:44:41,312, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-11-24 21:44:41,315, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:41,315, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:41,631, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-11-24 21:44:41,631, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-11-24 21:44:42,403, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-11-24 21:44:42,403, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-11-24 21:44:42,404, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:42,404, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:42,820, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-11-24 21:44:42,820, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-11-24 21:44:43,558, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-11-24 21:44:43,558, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-11-24 21:44:43,559, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:43,559, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:43,816, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-11-24 21:44:43,816, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-11-24 21:44:44,233, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-11-24 21:44:44,233, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-11-24 21:44:44,234, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:44,234, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:44,520, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-11-24 21:44:44,520, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-11-24 21:44:45,259, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-11-24 21:44:45,259, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-11-24 21:44:45,260, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:45,260, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:45,625, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-11-24 21:44:45,625, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-11-24 21:44:46,353, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-11-24 21:44:46,353, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-11-24 21:44:46,355, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:46,355, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:46,548, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-11-24 21:44:46,548, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-11-24 21:44:46,884, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-11-24 21:44:46,884, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-11-24 21:44:46,885, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:46,885, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:47,200, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-11-24 21:44:47,200, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-11-24 21:44:47,986, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-11-24 21:44:47,986, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-11-24 21:44:47,988, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:47,988, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:48,245, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-11-24 21:44:48,245, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-11-24 21:44:48,844, data_manager.py, 73, INFO, Processing ticker T
# 2024-11-24 21:44:48,844, data_manager.py, 73, INFO, Processing ticker T
# 2024-11-24 21:44:48,845, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:48,845, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:49,269, data_manager.py, 83, INFO, Saving data for T by year
# 2024-11-24 21:44:49,269, data_manager.py, 83, INFO, Saving data for T by year
# 2024-11-24 21:44:49,929, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-11-24 21:44:49,929, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-11-24 21:44:49,930, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:49,930, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:50,235, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-11-24 21:44:50,235, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-11-24 21:44:50,923, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-11-24 21:44:50,923, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-11-24 21:44:50,924, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:50,924, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:51,217, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-11-24 21:44:51,217, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-11-24 21:44:51,931, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-11-24 21:44:51,931, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-11-24 21:44:51,933, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:51,933, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:52,268, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-11-24 21:44:52,268, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-11-24 21:44:52,993, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-11-24 21:44:52,993, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-11-24 21:44:52,994, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:52,994, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:53,232, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-11-24 21:44:53,232, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-11-24 21:44:53,941, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-11-24 21:44:53,941, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-11-24 21:44:53,942, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:53,942, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:54,239, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-11-24 21:44:54,239, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-11-24 21:44:54,927, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-11-24 21:44:54,927, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-11-24 21:44:54,929, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:54,929, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:55,255, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-11-24 21:44:55,255, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-11-24 21:44:55,975, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-11-24 21:44:55,975, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-11-24 21:44:55,976, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:55,976, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:56,329, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-11-24 21:44:56,329, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-11-24 21:44:57,067, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-11-24 21:44:57,067, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-11-24 21:44:57,068, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:57,068, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:57,385, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-11-24 21:44:57,385, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-11-24 21:44:58,116, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-11-24 21:44:58,116, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-11-24 21:44:58,117, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:58,117, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:58,458, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-11-24 21:44:58,458, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-11-24 21:44:59,127, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-11-24 21:44:59,127, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-11-24 21:44:59,129, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-11-24
# 2024-11-24 21:44:59,129, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:44:59,457, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-11-24 21:44:59,457, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-11-24 21:45:00,198, data_manager.py, 73, INFO, Processing ticker BK
# 2024-11-24 21:45:00,198, data_manager.py, 73, INFO, Processing ticker BK
# 2024-11-24 21:45:00,200, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:00,200, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:00,518, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-11-24 21:45:00,518, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-11-24 21:45:01,222, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-11-24 21:45:01,222, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-11-24 21:45:01,223, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:01,223, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:01,685, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-11-24 21:45:01,685, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-11-24 21:45:02,444, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-11-24 21:45:02,444, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-11-24 21:45:02,446, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:02,446, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:02,836, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-11-24 21:45:02,836, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-11-24 21:45:03,585, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-11-24 21:45:03,585, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-11-24 21:45:03,587, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:03,587, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:03,937, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-11-24 21:45:03,937, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-11-24 21:45:04,677, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-11-24 21:45:04,677, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-11-24 21:45:04,678, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:04,678, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-11-24 21:45:05,506, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-11-24 21:45:05,506, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-11-24 21:45:05,507, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-11-24 21:45:05,507, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-11-24 21:45:05,508, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-11-24 21:45:05,508, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-11-24 21:45:05,509, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:05,509, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:05,814, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-11-24 21:45:05,814, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-11-24 21:45:06,563, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-11-24 21:45:06,563, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-11-24 21:45:06,564, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:06,564, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:06,845, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-11-24 21:45:06,845, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-11-24 21:45:07,641, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-11-24 21:45:07,641, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-11-24 21:45:07,643, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:07,643, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:08,030, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-11-24 21:45:08,030, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-11-24 21:45:08,721, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-11-24 21:45:08,721, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-11-24 21:45:08,722, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:08,722, data_manager.py, 109, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:08,997, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-11-24 21:45:08,997, data_manager.py, 83, INFO, Saving data for BIIB by year
# 2024-11-24 21:45:09,730, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-11-24 21:45:09,730, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-11-24 21:45:09,731, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:09,731, data_manager.py, 109, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:10,043, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-11-24 21:45:10,043, data_manager.py, 83, INFO, Saving data for BLK by year
# 2024-11-24 21:45:10,768, data_manager.py, 73, INFO, Processing ticker BX
# 2024-11-24 21:45:10,768, data_manager.py, 73, INFO, Processing ticker BX
# 2024-11-24 21:45:10,769, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:10,769, data_manager.py, 109, INFO, Getting stock price data for BX from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:11,040, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-11-24 21:45:11,040, data_manager.py, 83, INFO, Saving data for BX by year
# 2024-11-24 21:45:11,543, data_manager.py, 73, INFO, Processing ticker BA
# 2024-11-24 21:45:11,543, data_manager.py, 73, INFO, Processing ticker BA
# 2024-11-24 21:45:11,544, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:11,544, data_manager.py, 109, INFO, Getting stock price data for BA from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:11,846, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-11-24 21:45:11,846, data_manager.py, 83, INFO, Saving data for BA by year
# 2024-11-24 21:45:12,595, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-11-24 21:45:12,595, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-11-24 21:45:12,596, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:12,596, data_manager.py, 109, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:12,859, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-11-24 21:45:12,859, data_manager.py, 83, INFO, Saving data for BKNG by year
# 2024-11-24 21:45:13,584, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-11-24 21:45:13,584, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-11-24 21:45:13,585, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:13,585, data_manager.py, 109, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:13,917, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-11-24 21:45:13,917, data_manager.py, 83, INFO, Saving data for BWA by year
# 2024-11-24 21:45:14,651, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-11-24 21:45:14,651, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-11-24 21:45:14,653, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:14,653, data_manager.py, 109, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:15,033, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-11-24 21:45:15,033, data_manager.py, 83, INFO, Saving data for BXP by year
# 2024-11-24 21:45:15,749, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-11-24 21:45:15,749, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-11-24 21:45:15,751, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:15,751, data_manager.py, 109, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:16,045, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-11-24 21:45:16,045, data_manager.py, 83, INFO, Saving data for BSX by year
# 2024-11-24 21:45:16,746, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-11-24 21:45:16,746, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-11-24 21:45:16,747, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:16,747, data_manager.py, 109, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:17,092, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-11-24 21:45:17,092, data_manager.py, 83, INFO, Saving data for BMY by year
# 2024-11-24 21:45:17,930, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-11-24 21:45:17,930, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-11-24 21:45:17,931, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:17,931, data_manager.py, 109, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:18,227, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-11-24 21:45:18,227, data_manager.py, 83, INFO, Saving data for AVGO by year
# 2024-11-24 21:45:18,667, data_manager.py, 73, INFO, Processing ticker BR
# 2024-11-24 21:45:18,667, data_manager.py, 73, INFO, Processing ticker BR
# 2024-11-24 21:45:18,669, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-11-24
# 2024-11-24 21:45:18,669, data_manager.py, 109, INFO, Getting stock price data for BR from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:45:18,927, data_manager.py, 83, INFO, Saving data for BR by year
# 2024-11-24 21:45:18,927, data_manager.py, 83, INFO, Saving data for BR by year
# 2024-11-24 21:45:19,462, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-11-24 21:45:19,462, data_manager.py, 73, INFO, Processing ticker BRO
# ...
# 2024-11-24 21:51:59,139, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-11-24
# 2024-11-24 21:51:59,139, data_manager.py, 109, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:51:59,467, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-11-24 21:51:59,467, data_manager.py, 83, INFO, Saving data for WAB by year
# 2024-11-24 21:52:00,212, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-11-24 21:52:00,212, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-11-24 21:52:00,213, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:00,213, data_manager.py, 109, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:00,541, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-11-24 21:52:00,541, data_manager.py, 83, INFO, Saving data for WBA by year
# 2024-11-24 21:52:01,312, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-11-24 21:52:01,312, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-11-24 21:52:01,314, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:01,314, data_manager.py, 109, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:01,642, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-11-24 21:52:01,642, data_manager.py, 83, INFO, Saving data for WMT by year
# 2024-11-24 21:52:02,449, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-11-24 21:52:02,449, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-11-24 21:52:02,450, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:02,450, data_manager.py, 109, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:02,795, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-11-24 21:52:02,795, data_manager.py, 83, INFO, Saving data for DIS by year
# 2024-11-24 21:52:03,561, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-11-24 21:52:03,561, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-11-24 21:52:03,562, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:03,562, data_manager.py, 109, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:03,916, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-11-24 21:52:03,916, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-11-24 21:52:04,501, data_manager.py, 73, INFO, Processing ticker WM
# 2024-11-24 21:52:04,501, data_manager.py, 73, INFO, Processing ticker WM
# 2024-11-24 21:52:04,503, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:04,503, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:04,836, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-11-24 21:52:04,836, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-11-24 21:52:05,602, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-11-24 21:52:05,602, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-11-24 21:52:05,603, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:05,603, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:05,869, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-11-24 21:52:05,869, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-11-24 21:52:06,694, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-11-24 21:52:06,694, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-11-24 21:52:06,696, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:06,696, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:07,024, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-11-24 21:52:07,024, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-11-24 21:52:07,785, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-11-24 21:52:07,785, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-11-24 21:52:07,786, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:07,786, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:08,113, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-11-24 21:52:08,113, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-11-24 21:52:08,997, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-11-24 21:52:08,997, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-11-24 21:52:08,998, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:08,998, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:09,338, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-11-24 21:52:09,338, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-11-24 21:52:10,061, data_manager.py, 73, INFO, Processing ticker WST
# 2024-11-24 21:52:10,061, data_manager.py, 73, INFO, Processing ticker WST
# 2024-11-24 21:52:10,062, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:10,062, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:10,483, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-11-24 21:52:10,483, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-11-24 21:52:11,279, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-11-24 21:52:11,279, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-11-24 21:52:11,281, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:11,281, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:11,559, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-11-24 21:52:11,559, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-11-24 21:52:12,315, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-11-24 21:52:12,315, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-11-24 21:52:12,316, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:12,316, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WRK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# 2024-11-24 21:52:13,421, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-11-24 21:52:13,421, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-11-24 21:52:13,424, data_manager.py, 101, WARNING, No data found for WRK
# 2024-11-24 21:52:13,424, data_manager.py, 101, WARNING, No data found for WRK
# 2024-11-24 21:52:13,426, data_manager.py, 73, INFO, Processing ticker WY
# 2024-11-24 21:52:13,426, data_manager.py, 73, INFO, Processing ticker WY
# 2024-11-24 21:52:13,427, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:13,427, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:13,773, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-11-24 21:52:13,773, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-11-24 21:52:14,524, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-11-24 21:52:14,524, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-11-24 21:52:14,525, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:14,525, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:14,842, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-11-24 21:52:14,842, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-11-24 21:52:15,597, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-11-24 21:52:15,597, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-11-24 21:52:15,598, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:15,598, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:15,975, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-11-24 21:52:15,975, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-11-24 21:52:16,740, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-11-24 21:52:16,740, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-11-24 21:52:16,741, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:16,741, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:17,037, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-11-24 21:52:17,037, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-11-24 21:52:17,742, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-11-24 21:52:17,742, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-11-24 21:52:17,743, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:17,743, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:18,062, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-11-24 21:52:18,062, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-11-24 21:52:18,890, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-11-24 21:52:18,890, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-11-24 21:52:18,891, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:18,891, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:19,210, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-11-24 21:52:19,210, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-11-24 21:52:19,908, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-11-24 21:52:19,908, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-11-24 21:52:19,909, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:19,909, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:20,249, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-11-24 21:52:20,249, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-11-24 21:52:20,981, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-11-24 21:52:20,981, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-11-24 21:52:20,982, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:20,982, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:21,230, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-11-24 21:52:21,230, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-11-24 21:52:21,620, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-11-24 21:52:21,620, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-11-24 21:52:21,622, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:21,622, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:21,946, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-11-24 21:52:21,946, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-11-24 21:52:22,732, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-11-24 21:52:22,732, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-11-24 21:52:22,734, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:22,734, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:23,019, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-11-24 21:52:23,019, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-11-24 21:52:23,801, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-11-24 21:52:23,801, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-11-24 21:52:23,802, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:23,802, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:24,111, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-11-24 21:52:24,111, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-11-24 21:52:24,833, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-11-24 21:52:24,833, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-11-24 21:52:24,834, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:24,834, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:25,218, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-11-24 21:52:25,218, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-11-24 21:52:25,995, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-11-24 21:52:25,995, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-11-24 21:52:25,997, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-11-24
# 2024-11-24 21:52:25,997, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-11-24
# [*********************100%***********************]  1 of 1 completed
# 2024-11-24 21:52:26,216, data_manager.py, 83, INFO, Saving data for ZTS by year
# 2024-11-24 21:52:26,216, data_manager.py, 83, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-11-24 21:52:26,595, data_manager.py, 121, INFO, Creating features data.
# 2024-11-24 21:52:26,595, data_manager.py, 121, INFO, Creating features data.
# 2024-11-24 21:52:26,597, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# 2024-11-24 21:52:26,597, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\prsrivastava\.conda\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-11-24 21:52:27,969, data_manager.py, 140, INFO, Creating features
# 2024-11-24 21:52:27,969, data_manager.py, 140, INFO, Creating features
# c:\Users\prsrivastava\DSI_Demo\production\01_materials\labs\../../05_src\data_manager.py:142: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-11-24 21:52:28,133, data_manager.py, 158, INFO, Creating target
# 2024-11-24 21:52:28,133, data_manager.py, 158, INFO, Creating target
# c:\Users\prsrivastava\DSI_Demo\production\01_materials\labs\../../05_src\data_manager.py:159: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-11-24 21:52:28,171, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-11-24 21:52:28,171, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
